# %% [markdown]
# ## Count Objects in Image
# _____

# %% [markdown]
# Counting objects in an image is the task of computer vision. There are a bunch of computer vision libraries in Python that we can use for this task, such as OpenCV, TensorFlow, PyTorch, Scikit-image. But in this notebook, I will use a very simple approach to count objects in an image using `cvlib`. This is a simple, high level, and easy to use computer vision library in Python.
#
# By using the features of this library we can count the number of objects in an image. To use this library, make sure you have OpenCV and TensorFlow installed in your systems. You can easily install it by using the pip command:

# %% [raw]
# pip install cvlib

# %% [markdown]
# Now let’s see how to use the cvlib library to count the number of objects in an image using the Python programming language. I will first read an image by using the OpenCV library, then I will detect all the objects using cvlib and count the number of particular objects. The image that I am going to use for this task is shown below.

# %%
from IPython.display import Image, display

image_file = 'cars.jpg'
print(f'Displaying image with Image Name: {image_file}')
display(Image(filename=f'{image_file}', width=400))
# Out:
# Displaying image with Image Name: cars.jpg

# %% [markdown]
# As you can see the image that I am using here for the task of counting objects contains vehicles in it. So I will first detect all the vehicles and then count the number of cars out of them. So below is how we can count the number of cars in an image:

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox
from numpy.lib.polynomial import poly

image = cv2.imread('cars.jpg')
box, label, count = cv.detect_common_objects(image)
output = draw_bbox(image, box, label, count)

plt.imshow(output)
#plt.savefig('count_objects.jpg')
plt.show()
                   
print("Number of cars in this image are " +str(label.count('car')))
# Out:
# Number of cars in this image are 14

# %% [markdown]
# ### Summary
# So this is how we can count the number of objects by using the `cvlib` library. We can use this library for all the tasks of computer vision.
